# %%
from bandit import Bandit, EpsilonGreedy, ThompsonSampling, Visualization, comparison

# %% [markdown]
# ## Initializing Constants

# %%
Bandit_Reward = [1, 2, 3, 4]
NumberOfTrials = 20000

# %% [markdown]
# ## Epsilon - Greedy Algorithm

# %%
res = EpsilonGreedy(Bandit).experiment(Bandit_Reward, NumberOfTrials)

# %%
EpsilonGreedy(Bandit).report(NumberOfTrials, res, algorithm = "EpsilonGreedy")
# Out:
# Bandit with True Win Rate 1 - Pulled 3.0 times - Estimated average reward - 1.6187
# --------------------------------------------------
# Bandit with True Win Rate 2 - Pulled 22.0 times - Estimated average reward - 1.7103
# --------------------------------------------------
# Bandit with True Win Rate 3 - Pulled 1.0 times - Estimated average reward - 0.1141
# --------------------------------------------------
# Bandit with True Win Rate 4 - Pulled 19974.0 times - Estimated average reward - 3.9941
# --------------------------------------------------
# Cumulative Reward : 79819.76155059988
# Total Average Reward: 3.991
#
# Cumulative Regret : 180.23844940011622
# Total Average Regret: -0.009
#
# Percent suboptimal : 0.0013

# %% [markdown]
# ## Visualizing Learning Curve of Epsilon Greedy Algorithm

# %%
Visualization().plot1(NumberOfTrials, res, 'Epsilon Greedy')

# %% [markdown]
# ## Thomspon Sampling

# %%
res1 = ThompsonSampling(Bandit).experiment(Bandit_Reward, NumberOfTrials)

# %%
ThompsonSampling(Bandit).report(NumberOfTrials, res1, 'ThompsonSampling')
# Out:
# Bandit with True Win Rate 1 - Pulled 4 times - Estimated average reward - 0.5235
# --------------------------------------------------
# Bandit with True Win Rate 2 - Pulled 2 times - Estimated average reward - 1.1696
# --------------------------------------------------
# Bandit with True Win Rate 3 - Pulled 0 times - Estimated average reward - 0.0
# --------------------------------------------------
# Bandit with True Win Rate 4 - Pulled 19994 times - Estimated average reward - 3.999
# --------------------------------------------------
# Cumulative Reward : 79966.06090042338
# Total Average Reward: 3.9983
#
# Cumulative Regret : 33.93909957661526
# Total Average Regret: -0.0017

# %% [markdown]
# ## Visualizing Learning Curve of Thompson Sampling

# %%
Visualization().plot1( NumberOfTrials,res1, algorithm ='Thompson Sampling')

# %% [markdown]
# ## Comparison of Epsilon Greedy and Thompson Sampling

# %% [markdown]
# ### 1. Cumulative Regret and Reward

# %%
Visualization().plot2(res, res1)

# %% [markdown]
# ### 2. Cumulative Average Reward

# %%
comparison(NumberOfTrials, res, res1)
