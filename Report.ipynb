# %%
from bandit import Bandit, EpsilonGreedy, ThompsonSampling, Visualization, comparison

# %% [markdown]
# ## Initializing Constants

# %%
Bandit_Reward = [1, 2, 3, 4]
NumberOfTrials = 20000

# %% [markdown]
# ## Epsilon - Greedy Algorithm

# %%
res = EpsilonGreedy(Bandit).experiment(Bandit_Reward, NumberOfTrials)

# %%
EpsilonGreedy(Bandit).report(NumberOfTrials, res, algorithm = "EpsilonGreedy")
# Out:
# Bandit with True Win Rate 1 - Pulled 3.0 times - Estimated average reward - 0.4822 - Estimated average regret - 0.5178
# --------------------------------------------------
# Bandit with True Win Rate 2 - Pulled 5.0 times - Estimated average reward - 1.8111 - Estimated average regret - 0.1889
# --------------------------------------------------
# Bandit with True Win Rate 3 - Pulled 1.0 times - Estimated average reward - 3.2334 - Estimated average regret - -0.2334
# --------------------------------------------------
# Bandit with True Win Rate 4 - Pulled 19991.0 times - Estimated average reward - 4.0054 - Estimated average regret - -0.0054
# --------------------------------------------------
# Cumulative Reward : 80085.90290648055
#
# Cumulative Regret : -85.90290648055088
#
# Percent suboptimal : 0.0004

# %% [markdown]
# ## Visualizing Learning Curve of Epsilon Greedy Algorithm

# %%
Visualization().plot1(NumberOfTrials, res, 'Epsilon Greedy')

# %% [markdown]
# ## Thomspon Sampling

# %%
res1 = ThompsonSampling(Bandit).experiment(Bandit_Reward, NumberOfTrials)

# %%
ThompsonSampling(Bandit).report(NumberOfTrials, res1, 'ThompsonSampling')
# Out:
# Bandit with True Win Rate 1 - Pulled 1 times - Estimated average reward - 0.4232 - Estimated average regret - 0.5768
# --------------------------------------------------
# Bandit with True Win Rate 2 - Pulled 7 times - Estimated average reward - 1.6509 - Estimated average regret - 0.3491
# --------------------------------------------------
# Bandit with True Win Rate 3 - Pulled 2610 times - Estimated average reward - 2.9725 - Estimated average regret - 0.0275
# --------------------------------------------------
# Bandit with True Win Rate 4 - Pulled 17382 times - Estimated average reward - 3.997 - Estimated average regret - 0.003
# --------------------------------------------------
# Cumulative Reward : 77254.95414407455
#
# Cumulative Regret : 2745.0458559254475

# %% [markdown]
# ## Visualizing Learning Curve of Thompson Sampling

# %%
Visualization().plot1( NumberOfTrials,res1, algorithm ='Thompson Sampling')

# %% [markdown]
# ## Comparison of Epsilon Greedy and Thompson Sampling

# %% [markdown]
# ### 1. Cumulative Regret and Reward

# %%
Visualization().plot2(res, res1)

# %% [markdown]
# ### 2. Cumulative Average Reward

# %%
comparison(NumberOfTrials, res, res1)
# Out:
# Total Reward Epsilon Greedy : 80085.90290648055
# Total Reward Thomspon Sampling : 77254.95414407455
#
# Total Regret Epsilon Greedy : -85.90290648055088
# Total Regret Thomspon Sampling : 2745.0458559254475
